# %%
import pickle
import requests
from bs4 import BeautifulSoup
import re
import time
import numpy as np
import pandas as pd
import seaborn as sea
import datetime
import matplotlib.pyplot as plt
import warnings
import random
from rankit.Merge import borda_count_merge
warnings.filterwarnings('ignore')

# %%
box_office_mojo = pd.read_csv("./data/box_office_mojo.csv", index_col=0)
imdb = pd.read_pickle("./data/imdb.pkl")
tmdb = pd.read_csv("./data/tmdb.csv", index_col=0)
cast_crew = pd.read_pickle("./data/cast_crew.pkl")

# %%
print(box_office_mojo.columns)
print(imdb.columns)
print(tmdb.columns)
print(cast_crew.columns)
# Out:
# Index(['gross', 'movie_name', 'release_date', 'theaters', 'title', 'url',
#        'tconst'],
#       dtype='object')
# Index(['awards', 'cast', 'cast_ids', 'critic_reviews', 'directors',
#        'directors_ids', 'genres', 'imdb_popularity', 'meta_score',
#        'mmpa_rating', 'number_user_ratings', 'tconst', 'user_rating',
#        'user_reviews'],
#       dtype='object')
# Index(['adult', 'backdrop_path', 'belongs_to_collection', 'budget', 'genres',
#        'homepage', 'id', 'imdb_id', 'original_language', 'original_title',
#        'overview', 'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'status_code', 'status_message',
#        'tagline', 'title', 'video', 'vote_average', 'vote_count'],
#       dtype='object')
# Index(['adult', 'also_known_as', 'biography', 'birthday', 'deathday', 'gender',
#        'homepage', 'id', 'imdb_id', 'known_for_department', 'name',
#        'place_of_birth', 'popularity', 'profile_path'],
#       dtype='object')

# %% [markdown]
# ### Data cleaning and processing for box office mojo data

# %%
box_office_mojo["gross"] = box_office_mojo["gross"].apply( 
                                lambda x: int(x[1:].replace(',', '')))
box_office_mojo["theaters"] = box_office_mojo["theaters"].apply( 
                                lambda x: int(x.replace(',', '')) if x !="-" else None)
box_office_mojo["theaters"].fillna(box_office_mojo["theaters"].median(), inplace=True)
# df['purchase'].astype(str).astype(int)

# %%
df = box_office_mojo.groupby("title")["movie_name"].count()

# %%
box_office_mojo.head()
# Out:
#        gross                                 movie_name release_date  \
# 0  126737428               Smokey and the Bandit (1977)   1977-05-27
# 1  116395460  Close Encounters of the Third Kind (1977)   1977-11-16
# 2   94213184                Saturday Night Fever (1977)   1977-12-16
# 3   50750000                    A Bridge Too Far (1977)   1977-06-15
# 4   47346365                            The Deep (1977)   1977-06-17
#
#    theaters                               title  \
# 0    2250.0               Smokey and the Bandit
# 1     650.0  Close Encounters of the Third Kind
# 2     726.0                Saturday Night Fever
# 3    2250.0                    A Bridge Too Far
# 4     731.0                            The Deep
#
#                                           url     tconst
# 0   /release/rl477136385/?ref_=bo_yld_table_2  tt0076729
# 1   /release/rl340428289/?ref_=bo_yld_table_3  tt0075860
# 2  /release/rl2926544385/?ref_=bo_yld_table_4  tt0076666
# 3   /release/rl139036161/?ref_=bo_yld_table_5  tt0075784
# 4  /release/rl3561784833/?ref_=bo_yld_table_6  tt0075925

# %% [markdown]
# ### Data cleaning and processing for imdb data

# %%
imdb['critic_reviews'] = imdb['critic_reviews'].astype(str).astype(int)
imdb['user_rating'] = imdb['user_rating'].astype(str).astype(float)
imdb["number_user_ratings"] = imdb["number_user_ratings"].apply( 
                                lambda x: int(x.replace(',', '')))
imdb["user_reviews"] = imdb["user_reviews"].apply( 
                                lambda x: int(x.replace(',', '')))
imdb["meta_score"] = imdb["meta_score"].apply( 
                                lambda x: float(x) if x != None else x)
imdb["imdb_popularity"] = imdb["imdb_popularity"].apply( 
                                lambda x: float(x) if x != None else x)
imdb['mmpa_rating'] = imdb['mmpa_rating'].astype(str)
imdb['reviews'] = imdb['critic_reviews'] + imdb['user_reviews']
imdb['ratings']  = imdb['number_user_ratings'] * imdb['user_rating'] 
imdb['directors']  = imdb['directors'].apply( 
                                lambda x: x[1:] if len(x) > 1 else x )
imdb["cast_crew_id"] = imdb["cast_ids"] + imdb["directors_ids"]

# %%
imdb["imdb_popularity"].fillna(imdb["imdb_popularity"].mean(), inplace=True)
imdb["meta_score"].fillna(imdb["meta_score"].mean(), inplace=True)

# %%
imdb.head()
# Out:
#    awards                                               cast  \
# 0       2           [Burt Reynolds, Sally Field, Jerry Reed]
# 1      53   [Richard Dreyfuss, François Truffaut, Teri Garr]
# 2      16   [John Travolta, Karen Lynn Gorney, Barry Miller]
# 3      11         [Sean Connery, Ryan O'Neal, Michael Caine]
# 4       3  [Jacqueline Bisset, Nick Nolte, Dick Anthony W...
#
#                             cast_ids  critic_reviews               directors  \
# 0  [nm0000608, nm0000398, nm0715274]              78           [Hal Needham]
# 1  [nm0000377, nm0000076, nm0000414]             220      [Steven Spielberg]
# 2  [nm0000237, nm0331186, nm0587944]              97           [John Badham]
# 3  [nm0000125, nm0641939, nm0000323]              55  [Richard Attenborough]
# 4  [nm0000302, nm0000560, nm0930454]              33           [Peter Yates]
#
#   directors_ids                          genres  imdb_popularity  meta_score  \
# 0   [nm0624102]                [Action, Comedy]         3.000000   50.000000
# 1   [nm0000229]                 [Drama, Sci-Fi]         2.943485   90.000000
# 2   [nm0000824]                  [Drama, Music]         1.000000   77.000000
# 3   [nm0000277]           [Drama, History, War]         2.000000   54.707366
# 4   [nm0946811]  [Adventure, Mystery, Thriller]         2.943485   41.000000
#
#   mmpa_rating  number_user_ratings     tconst  user_rating  user_reviews  \
# 0          PG                41965  tt0076729          7.0           191
# 1          PG               171550  tt0075860          7.6           411
# 2           R                65781  tt0076666          6.8           240
# 3          PG                48385  tt0075784          7.4           238
# 4          PG                10324  tt0075925          6.2            69
#
#    reviews    ratings                                  cast_crew_id
# 0      269   293755.0  [nm0000608, nm0000398, nm0715274, nm0624102]
# 1      631  1303780.0  [nm0000377, nm0000076, nm0000414, nm0000229]
# 2      337   447310.8  [nm0000237, nm0331186, nm0587944, nm0000824]
# 3      293   358049.0  [nm0000125, nm0641939, nm0000323, nm0000277]
# 4      102    64008.8  [nm0000302, nm0000560, nm0930454, nm0946811]

# %% [markdown]
# ### Data cleaning and processing for tmdb data

# %%
tmdb = tmdb[tmdb.status == "Released"]
tmdb['votes']  = tmdb['vote_average'] * tmdb['vote_count'] 
tmdb["runtime"].fillna(tmdb["runtime"].median(), inplace=True)
tmdb.rename(columns = {"popularity": "tmdb_popularity"}, inplace=True)

# %%
tmdb.head()
# Out:
#    adult                     backdrop_path  \
# 0  False  /hzjX8eA4u7tGz4d4kjTnsW4RNWK.jpg
# 1  False  /xATZyEpnZ0Z0iO9z5K8RZsraGKI.jpg
# 2  False  /gqTwlRkQ2FBCeeq6JxzCj4ctjHF.jpg
# 3  False  /qHryw7hcO1Gcd7xQmJfDYPTgNLX.jpg
# 4  False  /1Wg8AmasOfb3HvkaS33AzJ6puph.jpg
#
#                                belongs_to_collection      budget  \
# 0  {'id': 87220, 'name': 'Smokey and the Bandit C...   4300000.0
# 1                                                NaN  20000000.0
# 2  {'id': 288280, 'name': 'Saturday Night Fever C...   3500000.0
# 3                                                NaN  22000000.0
# 4                                                NaN         0.0
#
#                                               genres homepage       id  \
# 0  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...      NaN  11006.0
# 1  [{'id': 878, 'name': 'Science Fiction'}, {'id'...      NaN    840.0
# 2  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...      NaN  11009.0
# 3  [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...      NaN   5902.0
# 4  [{'id': 9648, 'name': 'Mystery'}, {'id': 53, '...      NaN  20416.0
#
#      imdb_id original_language                      original_title  ...  \
# 0  tt0076729                en               Smokey and the Bandit  ...
# 1  tt0075860                en  Close Encounters of the Third Kind  ...
# 2  tt0076666                en                Saturday Night Fever  ...
# 3  tt0075784                en                    A Bridge Too Far  ...
# 4  tt0075925                en                            The Deep  ...
#
#                                     spoken_languages    status status_code  \
# 0           [{'iso_639_1': 'en', 'name': 'English'}]  Released         NaN
# 1  [{'iso_639_1': 'hi', 'name': 'हिन्दी'}, {'iso_...  Released         NaN
# 2  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released         NaN
# 3  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released         NaN
# 4  [{'iso_639_1': 'fr', 'name': 'Français'}, {'is...  Released         NaN
#
#   status_message                                            tagline  \
# 0            NaN  What we have here is a total lack of respect f...
# 1            NaN                                  We are not alone.
# 2            NaN                                           Catch it
# 3            NaN  Out of the sky comes the screen's most incredi...
# 4            NaN      Is anything worth the terror of ... The Deep.
#
#                                 title  video  vote_average vote_count    votes
# 0               Smokey and the Bandit  False           6.8      347.0   2359.6
# 1  Close Encounters of the Third Kind  False           7.4     2206.0  16324.4
# 2                Saturday Night Fever  False           6.7      901.0   6036.7
# 3                    A Bridge Too Far  False           7.2      369.0   2656.8
# 4                            The Deep  False           6.2      100.0    620.0
#
# [5 rows x 28 columns]

# %% [markdown]
# ### Data cleaning and processing for actors and director data

# %%
cast_crew['popularity'] = cast_crew['popularity'].astype(str).astype(float)

# %%
cast_crew.head()
# Out:
#    adult                                      also_known_as  \
# 0  False  [George Walton Lucas Jr. , 乔治·卢卡斯, Джордж Лука...
# 1  False  [Mark Hamil, Mark Richard Hamill, Марк Хэмилл,...
# 2  False  [Гаррісон Форд, Харрисон Форд, هاريسون فورد, 해...
# 3  False  [Carrie Frances Fisher , Кэрри Фишер, Кэрри Фр...
# 4  False                             [Peter Wilton Cushing]
#
#                                            biography    birthday    deathday  \
# 0  George Walton Lucas Jr. (born May 14, 1944) is...  1944-05-14        None
# 1  Mark Richard Hamill (born September 25, 1951) ...  1951-09-25        None
# 2  Legendary Hollywood Icon Harrison Ford was bor...  1942-07-13        None
# 3  Carrie Frances Fisher (21 October 1956 - 27 De...  1956-10-21  2016-12-27
# 4  Peter Wilton Cushing, OBE  (26 May 1913 – 11 A...  1913-05-26  1994-08-11
#
#    gender                      homepage  id    imdb_id known_for_department  \
# 0       2                          None   1  nm0000184            Directing
# 1       2                          None   2  nm0000434               Acting
# 2       2                          None   3  nm0000148               Acting
# 3       1  http://www.carriefisher.com/   4  nm0000402               Acting
# 4       2                          None   5  nm0001088               Acting
#
#             name                               place_of_birth  popularity  \
# 0   George Lucas                     Modesto, California, USA       6.642
# 1    Mark Hamill                     Concord, California, USA       7.589
# 2  Harrison Ford                       Chicago, Illinois, USA      10.845
# 3  Carrie Fisher  Beverly Hills, Los Angeles, California, USA       3.878
# 4  Peter Cushing                  Kenley, Surrey, England, UK       2.704
#
#                        profile_path
# 0  /8qxin8urtFE0NqaZNFWOuV537bH.jpg
# 1  /fk8OfdReNltKZqOk2TZgkofCUFq.jpg
# 2  /7CcoVFTogQgex2kJkXKMe8qHZrC.jpg
# 3  /rfJtncHewKVnHjqpIZvjn24ESeC.jpg
# 4  /l0grZXcjqctESg7h6Jdp33pA3QG.jpg

# %% [markdown]
# ### Removing unwanted columns for modelling

# %%
# Removing unwanted columns in each dataset
box_office_mojo.drop(['url', "title", "gross"], inplace=True, axis=1)
imdb.drop(["critic_reviews", "user_reviews", "number_user_ratings", 
           "user_rating", "cast_ids", "directors_ids", "cast", "directors"], inplace=True, axis=1)
tmdb.drop(["belongs_to_collection", "backdrop_path", "title","id", "adult", "production_companies",
           "overview", "poster_path", "original_language", "production_countries",
          "video", "status_code", "status", "status_message", "release_date",
          "homepage", "spoken_languages", "genres","original_title", "tagline",
          "status", "title", "vote_average", "vote_count"], inplace=True, axis=1)
cast_crew.drop(["adult", "id", "also_known_as", "biography", "deathday",
               "birthday", "gender", "homepage", "known_for_department", 
               "place_of_birth", "profile_path", "name"], inplace=True, axis=1)

# %% [markdown]
# ### Merge the datasets

# %%
imdb_mer = imdb.groupby(imdb.tconst).first()
tmdb_mer = tmdb.groupby(tmdb.imdb_id).first()
box_office_mojo.set_index("tconst", inplace=True)
df = tmdb_mer.merge(imdb_mer, how ="inner", left_index=True, right_index=True)
data = box_office_mojo.merge(df, how ="inner", left_index=True, right_index=True)

# %%
cast_popularity = {}
for i in cast_crew.values:
    cast_popularity[i[0]] = i[1]

# %%
def get_popularity(cast_crew):
    popu = 0
    for person in cast_crew:
        if person in cast_popularity:
            popu += cast_popularity[person]
    return popu

# %%
# Summing up popularity of the cast and crew
data["actor_popularity"] = data["cast_crew_id"].apply(lambda x: get_popularity(x))

# %%
data.drop(['cast_crew_id'], inplace=True, axis=1)

# %%
data.head()
# Out:
#                                                   movie_name release_date  \
# tt0029583  Snow White and the Seven Dwarfs1983 Re-release...   1983-07-15
# tt0029583  Snow White and the Seven Dwarfs1987 Re-release...   1987-07-17
# tt0029583  Snow White and the Seven Dwarfs1993 Re-release...   1993-07-02
# tt0032455                     Fantasia1985 Re-release (1985)   1985-02-08
# tt0032455                     Fantasia1990 Re-release (1990)   1990-10-05
#
#            theaters     budget  tmdb_popularity      revenue  runtime  \
# tt0029583    1362.0  1488423.0           18.454  184925486.0     83.0
# tt0029583    1729.0  1488423.0           18.454  184925486.0     83.0
# tt0029583    1831.0  1488423.0           18.454  184925486.0     83.0
# tt0032455     225.0  2280000.0           15.459   83320000.0    124.0
# tt0032455     481.0  2280000.0           15.459   83320000.0    124.0
#
#              votes  awards                        genres  imdb_popularity  \
# tt0029583  31717.0      17  [Animation, Family, Fantasy]         2.943485
# tt0029583  31717.0      17  [Animation, Family, Fantasy]         2.943485
# tt0029583  31717.0      17  [Animation, Family, Fantasy]         2.943485
# tt0032455  12247.0       9  [Animation, Family, Fantasy]         2.943485
# tt0032455  12247.0       9  [Animation, Family, Fantasy]         2.943485
#
#            meta_score mmpa_rating  reviews    ratings  actor_popularity
# tt0029583        95.0           G      396  1285152.4             4.941
# tt0029583        95.0           G      396  1285152.4             4.941
# tt0029583        95.0           G      396  1285152.4             4.941
# tt0032455        96.0           G      433   650418.6             5.211
# tt0032455        96.0           G      433   650418.6             5.211

# %%
for i in data.columns:
    print(i)
# Out:
# movie_name
# release_date
# theaters
# budget
# tmdb_popularity
# revenue
# runtime
# votes
# awards
# genres
# imdb_popularity
# meta_score
# mmpa_rating
# reviews
# ratings
# actor_popularity

# %%
data = pd.concat([data, pd.get_dummies(data['mmpa_rating'])], axis=1)

# %%
# Save dataframe as csv
data.to_csv("./data/modelling_data.csv")
# Save dataframe as pickle
data.to_pickle("./data/modelling_data.pkl")

# %%
cast_crew[cast_crew.imdb_id =="nm0000093"]
# Out:
#        imdb_id  popularity
# 127  nm0000093      20.336

# %%
cast_crew[cast_crew.popularity == max(cast_crew["popularity"])]
# Out:
#        imdb_id  popularity
# 169  nm0000134      32.371

# %%
da
